# %% [markdown]
# ## 🧠 Key Insights
#
# 1. Sales peak in Q4 → likely seasonal demand
# 2. Top 20% of products generate most revenue (Pareto principle)
# 3. Certain stores consistently outperform others
#
# ## 💡 Recommendations
#
# - Increase inventory before peak seasons
# - Focus marketing on top products
# - Analyze underperforming stores

# %%
import seaborn as sns

sns.barplot(x=stores.index[:10], y=stores.values[:10])
plt.xticks(rotation=45)
plt.title("Top 10 Stores by Profit")
plt.show()
