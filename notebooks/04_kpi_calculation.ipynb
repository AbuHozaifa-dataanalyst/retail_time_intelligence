# %%
from retail_time_intelligence.kpi_calculations import (
    monthly_growth,
    top_stores,
    top_products
)

growth = monthly_growth(df)
stores = top_stores(df)
products = top_products(df)

# %% [markdown]
# ## 📊 KPI Insights
#
# - Growth shows month-over-month performance
# - Top stores help identify high-performing locations
# - Top products highlight best-selling items
