# %%
from retail_time_intelligence.transformations import merge_data, create_features
from retail_time_intelligence.time_intelligence import (
    calculate_mtd,
    calculate_ytd,
    rolling_sales
)

df = merge_data(data)
df = create_features(df)

df = calculate_mtd(df)
df = calculate_ytd(df)
df = rolling_sales(df, 7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       4     calculate_ytd,
#       5     rolling_sales
#       6 )
#       7
# ----> 8 df = merge_data(data)
#       9 df = create_features(df)
#      10
#      11 df = calculate_mtd(df)
#
# NameError: name 'data' is not defined

# %% [markdown]
# ### Add VISUALS

# %%
import matplotlib.pyplot as plt

df.groupby("full_date")["sales_amount"].sum().plot()
plt.title("Daily Sales Trend")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 df.groupby("full_date")["sales_amount"].sum().plot()
#       4 plt.title("Daily Sales Trend")
#       5 plt.show()
#
# NameError: name 'df' is not defined
