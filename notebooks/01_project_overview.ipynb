# %% [markdown]
# ## 🧠 Architecture
#
# This project follows a modular data pipeline:
#
# - `data_loader.py` → Load raw data
# - `transformations.py` → Clean & merge data
# - `time_intelligence.py` → MTD, YTD, rolling metrics
# - `kpi_calculations.py` → Business KPIs
#
# This ensures:
# - Reusability
# - Clean code
# - Production-ready design
